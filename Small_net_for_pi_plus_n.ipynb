# %%
import torch
import random
import math
import numpy as np
import pandas as pd
import torch.nn as nn
import lightning as L
import matplotlib.pyplot as plt

from torchmetrics import MetricCollection
from torchmetrics import MeanAbsoluteError
from torchmetrics import MeanSquaredError
from torchmetrics import R2Score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.utils.data import random_split
from torch.utils.data import Dataset, DataLoader, TensorDataset

def set_random_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)
    L.seed_everything(seed)

set_random_seed(1438)
# Out:
# Seed set to 1438

# %%
params_dict = {
    'feature_scaler': StandardScaler(),
    'label_scaler': StandardScaler(),
    'batch_size': 256,
    'net_architecture': [5,100,100,1],
    'activation_function': nn.ReLU,
    'optim_func': torch.optim.Adam,
    'lr': 0.001,
    'lr_factor':0.5,
    'lr_patience': 5,
    'lr_cooldown': 20,
}

# %% [markdown]
# # Подготовка данных

# %%
df = pd.read_csv('./data/clasdb_pi_plus_n.txt', delimiter='\t', header=None)
df.columns = ['Ebeam', 'W', 'Q2', 'cos_theta', 'phi', 'dsigma_dOmega', 'error', 'id']
df.loc[8314:65671, 'Ebeam'] = 5.754 # peculiarity of this dataset.
df['phi'] = df.phi.apply(lambda x: math.radians(x))
df['cos_phi'] = df['phi'].apply(lambda x: math.cos(x))
df = df.iloc[df[['Ebeam', 'W', 'Q2', 'cos_theta', 'phi']].drop_duplicates().index]
df = df.drop('id', axis=1)
df = df[df.dsigma_dOmega <= df.dsigma_dOmega.quantile(0.96)]
df = df[df['error'] <= df["error"].quantile(0.96)]
df = df.reset_index(drop=True)
df
# Out:
#        Ebeam     W   Q2  cos_theta       phi  dsigma_dOmega     error  \
# 0      1.515  1.11  0.3   0.793353  6.021386         2.1780  0.484013
# 1      1.515  1.27  0.3  -0.793353  6.021386         2.8950  0.454498
# 2      1.515  1.27  0.3  -0.923880  6.021386         2.4850  0.477752
# 3      1.515  1.29  0.3  -0.382683  0.261799         2.2030  0.443164
# 4      1.515  1.29  0.3  -0.382683  0.785398         4.1780  0.474797
# ...      ...   ...  ...        ...       ...            ...       ...
# 86104  5.499  2.01  4.0   0.975000  3.730641         0.1012  0.043165
# 86105  5.499  2.01  4.0   0.975000  3.992441         0.1199  0.076638
# 86106  5.499  2.01  4.0   0.975000  4.646939         0.1578  0.095391
# 86107  5.499  2.01  4.0   0.975000  4.777839         0.2346  0.158557
# 86108  5.499  2.01  4.0   0.975000  6.086836         0.1250  0.077753
#
#         cos_phi
# 0      0.965926
# 1      0.965926
# 2      0.965926
# 3      0.965926
# 4      0.707107
# ...         ...
# 86104 -0.831470
# 86105 -0.659346
# 86106 -0.065403
# 86107  0.065403
# 86108  0.980785
#
# [86109 rows x 8 columns]

# %%
feature_columns = ["Ebeam", "W",	"Q2",	"cos_theta", "cos_phi"]
feature_data = df[feature_columns]
label_data = df['dsigma_dOmega']


#TRAIN TEST SPLIT
X_train, X_residual, y_train, y_residual = train_test_split(feature_data,
                                                    label_data,
                                                    test_size=0.2,
                                                    random_state=42)

X_test, X_val, y_test, y_val = train_test_split(X_residual,
                                                y_residual,
                                                test_size=0.5,
                                                random_state=42)

# %%
#scale feature
scaler_feature = params_dict.get('feature_scaler')
X_train = X_train.reset_index(drop=True)
X_val = X_val.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)

columns_to_scale = list(X_train.columns)
X_train[columns_to_scale] = pd.DataFrame(scaler_feature.fit_transform(X_train[columns_to_scale]))
X_val[columns_to_scale] = pd.DataFrame(scaler_feature.transform(X_val[columns_to_scale]))
X_test[columns_to_scale] = pd.DataFrame(scaler_feature.transform(X_test[columns_to_scale]))

#scale target
scaler_target = params_dict.get('label_scaler')
y_train = pd.Series(scaler_target.fit_transform(y_train.to_frame())[:,0])
y_val = pd.Series(scaler_target.transform(y_val.to_frame())[:,0])
y_test = pd.Series(scaler_target.transform(y_test.to_frame())[:,0])

# %%
X_train = torch.tensor(X_train.values, dtype=torch.float32)
X_test = torch.tensor(X_test.values, dtype=torch.float32)
X_val = torch.tensor(X_val.values, dtype=torch.float32)

y_train = torch.tensor(y_train.values, dtype=torch.float32)
y_test = torch.tensor(y_test.values, dtype=torch.float32)
y_val = torch.tensor(y_val.values, dtype=torch.float32)

# %%
train_data = TensorDataset(X_train, y_train)
val_data = TensorDataset(X_val, y_val)
test_data = TensorDataset(X_test, y_test)

train_dataloader = DataLoader(train_data, batch_size=params_dict.get('batch_size'), shuffle=True)
val_dataloader = DataLoader(val_data, batch_size=params_dict.get('batch_size'), shuffle=False)
test_dataloader = DataLoader(test_data, batch_size=params_dict.get('batch_size'), shuffle=False)

# %% [markdown]
# # Создание модели

# %%
class NeuralNetwork(nn.Module):

    def __init__(self):
        super().__init__()

        self.net_architecture = params_dict.get('net_architecture')
        self.activation_function = params_dict.get('activation_function')

        self.network = nn.Sequential()
        for i in range(1,len(self.net_architecture)):
            self.network.append(nn.Linear(self.net_architecture[i-1], self.net_architecture[i]))
            if i!=len(self.net_architecture)-1:
                self.network.append(self.activation_function())

            else:
                pass

    def forward(self, x):
        return self.network(x)

# %%
model = NeuralNetwork()

# %% [markdown]
# # Обучение

# %%
class Pipeline(L.LightningModule):
    def __init__(self, model, params):
        super().__init__()

        self.model = model
        self.params = params
        self.criterion = torch.nn.MSELoss()
        self.optimizer = params_dict.get('optim_func')

        self.metrics = MetricCollection([
            MeanAbsoluteError(),
            MeanSquaredError(),
            R2Score()
        ])

        self.train_metrics = self.metrics.clone(postfix='/train')
        self.val_metrics = self.metrics.clone(postfix='/val')

    def configure_optimizers(self):
        optimizer = self.optimizer(self.parameters(), lr=self.params.get('lr'))

        lr_optim = ReduceLROnPlateau(optimizer = optimizer,
                                     mode = 'min',
                                     factor = self.params.get('lr_factor'),
                                     patience = self.params.get('lr_patience'),
                                     cooldown=self.params.get('lr_cooldown'),
                                     threshold=0.01
                                     )
        return {"optimizer": optimizer,
                "lr_scheduler": {
                    "scheduler": lr_optim,
                    "interval": "epoch",
                    "monitor": "val_loss",
                    "frequency": 2,
                    "name": 'lr_scheduler_monitoring'
                    },
                }

    def training_step(self, batch, batch_idx):
        x, y = batch
        out = self.model(x)
        loss = torch.sqrt(self.criterion(out.reshape(-1), y))
        self.train_metrics.update(out.reshape(-1), y)
        self.log("train_loss", loss, prog_bar=True)
        return loss


    def validation_step(self, batch, batch_idx):
        x, y = batch
        out = self.model(x)
        loss = torch.sqrt(self.criterion(out.reshape(-1), y))  #RMSE_Loss
        self.val_metrics.update(out.reshape(-1), y)
        self.log("val_loss", loss, prog_bar=True)

    def on_validation_epoch_end(self):
        self.log_dict(self.val_metrics.compute())
        self.val_metrics.reset()

    def on_train_epoch_end(self):
        self.log_dict(self.train_metrics.compute())
        self.train_metrics.reset()

    def test_step(self, batch, batch_idx):
        x, y = batch
        out = self.model(x)
        self.metrics.update(out.reshape(-1), y)
        self.test_labels.append(y.cpu())
        self.test_predictions.append(out.cpu())

    def on_test_start(self):
        self.test_labels = []
        self.test_predictions = []

    def on_test_epoch_end(self):
        self.log_dict(self.metrics.compute())
        self.metrics.reset()

        all_labels = torch.cat(self.test_labels)
        all_predictions = torch.cat(self.test_predictions)

        self.results_df = pd.DataFrame({
            'true_label': all_labels.numpy().flatten(),
            'prediction': all_predictions.numpy().flatten()
        })

    def predict_step(self, batch, batch_idx, dataloader_idx=0):
        x, y = batch
        out = self.model(x)
        return out

# %%
L.seed_everything(1438)

model = NeuralNetwork()
pl_model = Pipeline(model, params=params_dict)
trainer = L.Trainer(max_epochs=100)

trainer.fit(
    model=pl_model,
    train_dataloaders=train_dataloader,
    val_dataloaders=val_dataloader
)
# Out:
# Seed set to 1438
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | model         | NeuralNetwork    | 10.8 K | train
# 1 | criterion     | MSELoss          | 0      | train
# 2 | metrics       | MetricCollection | 0      | train
# 3 | train_metrics | MetricCollection | 0      | train
# 4 | val_metrics   | MetricCollection | 0      | train
# -----------------------------------------------------------
# 10.8 K    Trainable params
# 0         Non-trainable params
# 10.8 K    Total params
# 0.043     Total estimated model params size (MB)
# 20        Modules in train mode
# 0         Modules in eval mode
# /Users/golda/Library/Caches/pypoetry/virtualenvs/msu-interpol-6qN01YQ5-py3.14/lib/python3.14/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:433: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /Users/golda/Library/Caches/pypoetry/virtualenvs/msu-interpol-6qN01YQ5-py3.14/lib/python3.14/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:433: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 270/270 [00:01<00:00, 257.30it/s, v_num=7, train_loss=0.433]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/34 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▎         | 1/34 [00:00<00:00, 293.43it/s]
# Validation DataLoader 0:   6%|▌         | 2/34 [00:00<00:00, 242.36it/s]
# Validation DataLoader 0:   9%|▉         | 3/34 [00:00<00:00, 250.17it/s]
# Validation DataLoader 0:  12%|█▏        | 4/34 [00:00<00:00, 267.74it/s]
# Validation DataLoader 0:  15%|█▍        | 5/34 [00:00<00:00, 276.06it/s]
# Validation DataLoader 0:  18%|█▊        | 6/34 [00:00<00:00, 287.66it/s]
# Validation DataLoader 0:  21%|██        | 7/34 [00:00<00:00, 290.78it/s]
# Validation DataLoader 0:  24%|██▎       | 8/34 [00:00<00:00, 293.99it/s]
# Validation DataLoader 0:  26%|██▋       | 9/34 [00:00<00:00, 290.43it/s]
# Validation DataLoader 0:  29%|██▉       | 10/34 [00:00<00:00, 294.66it/s]
# Validation DataLoader 0:  32%|███▏      | 11/34 [00:00<00:00, 291.62it/s]
# Validation DataLoader 0:  35%|███▌      | 12/34 [00:00<00:00, 296.63it/s]
# Validation DataLoader 0:  38%|███▊      | 13/34 [00:00<00:00, 300.34it/s]
# Validation DataLoader 0:  41%|████      | 14/34 [00:00<00:00, 303.15it/s]
# Validation DataLoader 0:  44%|████▍     | 15/34 [00:00<00:00, 303.84it/s]
# Validation DataLoader 0:  47%|████▋     | 16/34 [00:00<00:00, 300.63it/s]
# Validation DataLoader 0:  50%|█████     | 17/34 [00:00<00:00, 300.78it/s]
# Validation DataLoader 0:  53%|█████▎    | 18/34 [00:00<00:00, 301.34it/s]
# Validation DataLoader 0:  56%|█████▌    | 19/34 [00:00<00:00, 300.85it/s]
# Validation DataLoader 0:  59%|█████▉    | 20/34 [00:00<00:00, 300.12it/s]
# Validation DataLoader 0:  62%|██████▏   | 21/34 [00:00<00:00, 301.32it/s]
# Validation DataLoader 0:  65%|██████▍   | 22/34 [00:00<00:00, 301.37it/s]
# Validation DataLoader 0:  68%|██████▊   | 23/34 [00:00<00:00, 301.54it/s]
# Validation DataLoader 0:  71%|███████   | 24/34 [00:00<00:00, 298.93it/s]
# Validation DataLoader 0:  74%|███████▎  | 25/34 [00:00<00:00, 299.61it/s]
# Validation DataLoader 0:  76%|███████▋  | 26/34 [00:00<00:00, 299.14it/s]
# Validation DataLoader 0:  79%|███████▉  | 27/34 [00:00<00:00, 299.69it/s]
# Validation DataLoader 0:  82%|████████▏ | 28/34 [00:00<00:00, 301.17it/s]
# Validation DataLoader 0:  85%|████████▌ | 29/34 [00:00<00:00, 301.70it/s]
# Validation DataLoader 0:  88%|████████▊ | 30/34 [00:00<00:00, 301.56it/s]
# Validation DataLoader 0:  91%|█████████ | 31/34 [00:00<00:00, 302.86it/s]
# Validation DataLoader 0:  94%|█████████▍| 32/34 [00:00<00:00, 302.48it/s]
# Validation DataLoader 0:  97%|█████████▋| 33/34 [00:00<00:00, 303.15it/s]
# Validation DataLoader 0: 100%|██████████| 34/34 [00:00<00:00, 304.30it/s]
# Epoch 1: 100%|██████████| 270/270 [00:01<00:00, 266.98it/s, v_num=7, train_loss=0.594, val_loss=0.449]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/34 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▎         | 1/34 [00:00<00:00, 295.19it/s]
# Validation DataLoader 0:   6%|▌         | 2/34 [00:00<00:00, 305.50it/s]
# Validation DataLoader 0:   9%|▉         | 3/34 [00:00<00:00, 310.76it/s]
# Validation DataLoader 0:  12%|█▏        | 4/34 [00:00<00:00, 298.02it/s]
# Validation DataLoader 0:  15%|█▍        | 5/34 [00:00<00:00, 303.55it/s]
# Validation DataLoader 0:  18%|█▊        | 6/34 [00:00<00:00, 300.86it/s]
# Validation DataLoader 0:  21%|██        | 7/34 [00:00<00:00, 304.83it/s]
# Validation DataLoader 0:  24%|██▎       | 8/34 [00:00<00:00, 307.61it/s]
# Validation DataLoader 0:  26%|██▋       | 9/34 [00:00<00:00, 308.78it/s]
# Validation DataLoader 0:  29%|██▉       | 10/34 [00:00<00:00, 310.97it/s]
# Validation DataLoader 0:  32%|███▏      | 11/34 [00:00<00:00, 313.45it/s]
# Validation DataLoader 0:  35%|███▌      | 12/34 [00:00<00:00, 314.71it/s]
# Validation DataLoader 0:  38%|███▊      | 13/34 [00:00<00:00, 313.37it/s]
# Validation DataLoader 0:  41%|████      | 14/34 [00:00<00:00, 310.51it/s]
# Validation DataLoader 0:  44%|████▍     | 15/34 [00:00<00:00, 312.61it/s]
# Validation DataLoader 0:  47%|████▋     | 16/34 [00:00<00:00, 314.35it/s]
# Validation DataLoader 0:  50%|█████     | 17/34 [00:00<00:00, 312.10it/s]
# Validation DataLoader 0:  53%|█████▎    | 18/34 [00:00<00:00, 312.28it/s]
# Validation DataLoader 0:  56%|█████▌    | 19/34 [00:00<00:00, 313.75it/s]
# Validation DataLoader 0:  59%|█████▉    | 20/34 [00:00<00:00, 313.85it/s]
# Validation DataLoader 0:  62%|██████▏   | 21/34 [00:00<00:00, 315.71it/s]
# Validation DataLoader 0:  65%|██████▍   | 22/34 [00:00<00:00, 316.78it/s]
# Validation DataLoader 0:  68%|██████▊   | 23/34 [00:00<00:00, 317.28it/s]
# Validation DataLoader 0:  71%|███████   | 24/34 [00:00<00:00, 317.68it/s]
# Validation DataLoader 0:  74%|███████▎  | 25/34 [00:00<00:00, 316.20it/s]
# Validation DataLoader 0:  76%|███████▋  | 26/34 [00:00<00:00, 316.44it/s]
# Validation DataLoader 0:  79%|███████▉  | 27/34 [00:00<00:00, 316.55it/s]
# Validation DataLoader 0:  82%|████████▏ | 28/34 [00:00<00:00, 317.84it/s]
# Validation DataLoader 0:  85%|████████▌ | 29/34 [00:00<00:00, 319.93it/s]
# Validation DataLoader 0:  88%|████████▊ | 30/34 [00:00<00:00, 320.57it/s]
# Validation DataLoader 0:  91%|█████████ | 31/34 [00:00<00:00, 320.19it/s]
# Validation DataLoader 0:  94%|█████████▍| 32/34 [00:00<00:00, 321.01it/s]
# Validation DataLoader 0:  97%|█████████▋| 33/34 [00:00<00:00, 319.08it/s]
# Validation DataLoader 0: 100%|██████████| 34/34 [00:00<00:00, 320.11it/s]
# Epoch 2: 100%|██████████| 270/270 [00:01<00:00, 231.56it/s, v_num=7, train_loss=0.308, val_loss=0.418]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/34 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▎         | 1/34 [00:00<00:00, 321.23it/s]
# Validation DataLoader 0:   6%|▌         | 2/34 [00:00<00:00, 327.76it/s]
# Validation DataLoader 0:   9%|▉         | 3/34 [00:00<00:00, 316.26it/s]
# Validation DataLoader 0:  12%|█▏        | 4/34 [00:00<00:00, 331.05it/s]
# Validation DataLoader 0:  15%|█▍        | 5/34 [00:00<00:00, 339.75it/s]
# Validation DataLoader 0:  18%|█▊        | 6/34 [00:00<00:00, 332.49it/s]
# Validation DataLoader 0:  21%|██        | 7/34 [00:00<00:00, 322.11it/s]
# Validation DataLoader 0:  24%|██▎       | 8/34 [00:00<00:00, 317.51it/s]
# Validation DataLoader 0:  26%|██▋       | 9/34 [00:00<00:00, 321.90it/s]
# Validation DataLoader 0:  29%|██▉       | 10/34 [00:00<00:00,
/s]
# Validation DataLoader 0:  41%|████      | 14/34 [00:00<00:00, 301.54it/s]
# Validation DataLoader 0:  44%|████▍     | 15/34 [00:00<00:00, 301.58it/s]
# Validation DataLoader 0:  47%|████▋     | 16/34 [00:00<00:00, 302.13it/s]
# Validation DataLoader 0:  50%|█████     | 17/34 [00:00<00:00, 300.83it/s]
# Validation DataLoader 0:  53%|█████▎    | 18/34 [00:00<00:00, 298.30it/s]
# Validation DataLoader 0:  56%|█████▌    | 19/34 [00:00<00:00, 299.29it/s]
# Validation DataLoader 0:  59%|█████▉    | 20/34 [00:00<00:00, 298.85it/s]
# Validation DataLoader 0:  62%|██████▏   | 21/34 [00:00<00:00, 298.70it/s]
# Validation DataLoader 0:  65%|██████▍   | 22/34 [00:00<00:00, 299.85it/s]
# Validation DataLoader 0:  68%|██████▊   | 23/34 [00:00<00:00, 299.80it/s]
# Validation DataLoader 0:  71%|███████   | 24/34 [00:00<00:00, 301.99it/s]
# Validation DataLoader 0:  74%|███████▎  | 25/34 [00:00<00:00, 302.99it/s]
# Validation DataLoader 0:  76%|███████▋  | 26/34 [00:00<00:00, 300.53it/s]
# Validation DataLoader 0:  79%|███████▉  | 27/34 [00:00<00:00, 300.79it/s]
# Validation DataLoader 0:  82%|████████▏ | 28/34 [00:00<00:00, 298.56it/s]
# Validation DataLoader 0:  85%|████████▌ | 29/34 [00:00<00:00, 299.88it/s]
# Validation DataLoader 0:  88%|████████▊ | 30/34 [00:00<00:00, 299.82it/s]
# Validation DataLoader 0:  91%|█████████ | 31/34 [00:00<00:00, 300.19it/s]
# Validation DataLoader 0:  94%|█████████▍| 32/34 [00:00<00:00, 302.30it/s]
# Validation DataLoader 0:  97%|█████████▋| 33/34 [00:00<00:00, 303.08it/s]
# Validation DataLoader 0: 100%|██████████| 34/34 [00:00<00:00, 302.78it/s]
# Epoch 98: 100%|██████████| 270/270 [00:01<00:00, 211.15it/s, v_num=7, train_loss=0.301, val_loss=0.219]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/34 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▎         | 1/34 [00:00<00:00, 342.48it/s]
# Validation DataLoader 0:   6%|▌         | 2/34 [00:00<00:00, 334.51it/s]
# Validation DataLoader 0:   9%|▉         | 3/34 [00:00<00:00, 333.19it/s]
# Validation DataLoader 0:  12%|█▏        | 4/34 [00:00<00:00, 304.62it/s]
# Validation DataLoader 0:  15%|█▍        | 5/34 [00:00<00:00, 308.60it/s]
# Validation DataLoader 0:  18%|█▊        | 6/34 [00:00<00:00, 306.75it/s]
# Validation DataLoader 0:  21%|██        | 7/34 [00:00<00:00, 299.08it/s]
# Validation DataLoader 0:  24%|██▎       | 8/34 [00:00<00:00, 301.91it/s]
# Validation DataLoader 0:  26%|██▋       | 9/34 [00:00<00:00, 294.18it/s]
# Validation DataLoader 0:  29%|██▉       | 10/34 [00:00<00:00, 298.64it/s]
# Validation DataLoader 0:  32%|███▏      | 11/34 [00:00<00:00, 298.28it/s]
# Validation DataLoader 0:  35%|███▌      | 12/34 [00:00<00:00, 298.37it/s]
# Validation DataLoader 0:  38%|███▊      | 13/34 [00:00<00:00, 297.57it/s]
# Validation DataLoader 0:  41%|████      | 14/34 [00:00<00:00, 295.31it/s]
# Validation DataLoader 0:  44%|████▍     | 15/34 [00:00<00:00, 293.21it/s]
# Validation DataLoader 0:  47%|████▋     | 16/34 [00:00<00:00, 293.34it/s]
# Validation DataLoader 0:  50%|█████     | 17/34 [00:00<00:00, 292.59it/s]
# Validation DataLoader 0:  53%|█████▎    | 18/34 [00:00<00:00, 295.01it/s]
# Validation DataLoader 0:  56%|█████▌    | 19/34 [00:00<00:00, 297.10it/s]
# Validation DataLoader 0:  59%|█████▉    | 20/34 [00:00<00:00, 295.56it/s]
# Validation DataLoader 0:  62%|██████▏   | 21/34 [00:00<00:00, 297.86it/s]
# Validation DataLoader 0:  65%|██████▍   | 22/34 [00:00<00:00, 297.61it/s]
# Validation DataLoader 0:  68%|██████▊   | 23/34 [00:00<00:00, 296.74it/s]
# Validation DataLoader 0:  71%|███████   | 24/34 [00:00<00:00, 299.13it/s]
# Validation DataLoader 0:  74%|███████▎  | 25/34 [00:00<00:00, 299.38it/s]
# Validation DataLoader 0:  76%|███████▋  | 26/34 [00:00<00:00, 298.96it/s]
# Validation DataLoader 0:  79%|███████▉  | 27/34 [00:00<00:00, 298.77it/s]
# Validation DataLoader 0:  82%|████████▏ | 28/34 [00:00<00:00, 299.86it/s]
# Validation DataLoader 0:  85%|████████▌ | 29/34 [00:00<00:00, 300.53it/s]
# Validation DataLoader 0:  88%|████████▊ | 30/34 [00:00<00:00, 300.22it/s]
# Validation DataLoader 0:  91%|█████████ | 31/34 [00:00<00:00, 299.77it/s]
# Validation DataLoader 0:  94%|█████████▍| 32/34 [00:00<00:00, 299.70it/s]
# Validation DataLoader 0:  97%|█████████▋| 33/34 [00:00<00:00, 299.94it/s]
# Validation DataLoader 0: 100%|██████████| 34/34 [00:00<00:00, 297.34it/s]
# Epoch 99: 100%|██████████| 270/270 [00:01<00:00, 219.80it/s, v_num=7, train_loss=0.157, val_loss=0.219]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/34 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▎         | 1/34 [00:00<00:00, 343.54it/s]
# Validation DataLoader 0:   6%|▌         | 2/34 [00:00<00:00, 339.28it/s]
# Validation DataLoader 0:   9%|▉         | 3/34 [00:00<00:00, 318.17it/s]
# Validation DataLoader 0:  12%|█▏        | 4/34 [00:00<00:00, 301.23it/s]
# Validation DataLoader 0:  15%|█▍        | 5/34 [00:00<00:00, 298.54it/s]
# Validation DataLoader 0:  18%|█▊        | 6/34 [00:00<00:00, 281.51it/s]
# Validation DataLoader 0:  21%|██        | 7/34 [00:00<00:00, 291.62it/s]
# Validation DataLoader 0:  24%|██▎       | 8/34 [00:00<00:00, 289.13it/s]
# Validation DataLoader 0:  26%|██▋       | 9/34 [00:00<00:00, 287.68it/s]
# Validation DataLoader 0:  29%|██▉       | 10/34 [00:00<00:00, 289.92it/s]
# Validation DataLoader 0:  32%|███▏      | 11/34 [00:00<00:00, 285.21it/s]
# Validation DataLoader 0:  35%|███▌      | 12/34 [00:00<00:00, 288.43it/s]
# Validation DataLoader 0:  38%|███▊      | 13/34 [00:00<00:00, 292.19it/s]
# Validation DataLoader 0:  41%|████      | 14/34 [00:00<00:00, 291.30it/s]
# Validation DataLoader 0:  44%|████▍     | 15/34 [00:00<00:00, 293.93it/s]
# Validation DataLoader 0:  47%|████▋     | 16/34 [00:00<00:00, 296.84it/s]
# Validation DataLoader 0:  50%|█████     | 17/34 [00:00<00:00, 295.80it/s]
# Validation DataLoader 0:  53%|█████▎    | 18/34 [00:00<00:00, 297.83it/s]
# Validation DataLoader 0:  56%|█████▌    | 19/34 [00:00<00:00, 294.28it/s]
# Validation DataLoader 0:  59%|█████▉    | 20/34 [00:00<00:00, 294.49it/s]
# Validation DataLoader 0:  62%|██████▏   | 21/34 [00:00<00:00, 296.59it/s]
# Validation DataLoader 0:  65%|██████▍   | 22/34 [00:00<00:00, 296.46it/s]
# Validation DataLoader 0:  68%|██████▊   | 23/34 [00:00<00:00, 296.86it/s]
# Validation DataLoader 0:  71%|███████   | 24/34 [00:00<00:00, 299.50it/s]
# Validation DataLoader 0:  74%|███████▎  | 25/34 [00:00<00:00, 300.12it/s]
# Validation DataLoader 0:  76%|███████▋  | 26/34 [00:00<00:00, 298.05it/s]
# Validation DataLoader 0:  79%|███████▉  | 27/34 [00:00<00:00, 298.54it/s]
# Validation DataLoader 0:  82%|████████▏ | 28/34 [00:00<00:00, 298.36it/s]
# Validation DataLoader 0:  85%|████████▌ | 29/34 [00:00<00:00, 296.87it/s]
# Validation DataLoader 0:  88%|████████▊ | 30/34 [00:00<00:00, 298.15it/s]
# Validation DataLoader 0:  91%|█████████ | 31/34 [00:00<00:00, 297.75it/s]
# Validation DataLoader 0:  94%|█████████▍| 32/34 [00:00<00:00, 299.71it/s]
# Validation DataLoader 0:  97%|█████████▋| 33/34 [00:00<00:00, 300.27it/s]
# Validation DataLoader 0: 100%|██████████| 34/34 [00:00<00:00, 299.25it/s]
# Epoch 99: 100%|██████████| 270/270 [00:01<00:00, 199.27it/s, v_num=7, train_loss=0.157, val_loss=0.218]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|██████████| 270/270 [00:01<00:00, 197.57it/s, v_num=7, train_loss=0.157, val_loss=0.218]

# %% [markdown]
# # Результаты

# %%
predictions = trainer.predict(dataloaders=test_dataloader)
predictions = torch.cat(predictions, dim=0)
predictions = scaler_target.inverse_transform(predictions)
predictions
# Out:
# /Users/golda/Library/Caches/pypoetry/virtualenvs/msu-interpol-6qN01YQ5-py3.14/lib/python3.14/site-packages/lightning/pytorch/trainer/connectors/checkpoint_connector.py:149: `.predict(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `.predict(ckpt_path='best')` to use the best model or `.predict(ckpt_path='last')` to use the last model. If you pass a value, this warning will be silenced.
# Restoring states from the checkpoint path at /Users/golda/Documents/Study/MSU_interpol/lightning_logs/version_7/checkpoints/epoch=99-step=27000.ckpt
# Loaded model weights from the checkpoint at /Users/golda/Documents/Study/MSU_interpol/lightning_logs/version_7/checkpoints/epoch=99-step=27000.ckpt
# /Users/golda/Library/Caches/pypoetry/virtualenvs/msu-interpol-6qN01YQ5-py3.14/lib/python3.14/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:433: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Predicting DataLoader 0: 100%|██████████| 34/34 [00:00<00:00, 497.90it/s]
# array([[0.24110802],
#        [0.34002287],
#        [0.90078171],
#        ...,
#        [0.74839994],
#        [0.438632  ],
#        [0.22329707]], shape=(8611, 1))

# %%
y_test = y_test.reshape(-1, 1)
y_test = scaler_target.inverse_transform(y_test)
y_test
# Out:
# array([[0.15873   ],
#        [0.39740001],
#        [0.7077    ],
#        ...,
#        [0.68493   ],
#        [0.4209    ],
#        [0.22423002]], shape=(8611, 1))

# %%
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)

print(f"Mean Absolute Error: {mae:.5f}")
print(f"Mean Squared Error: {mse:.5f}")
# Out:
# Mean Absolute Error: 0.08342
# Mean Squared Error: 0.01543

# %%
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)

print(f"Mean Absolute Error: {mae:.5f}")
print(f"Mean Squared Error: {mse:.5f}")
# Out:
# Mean Absolute Error: 0.08458
# Mean Squared Error: 0.01520

# %%
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)

print(f"Mean Absolute Error: {mae:.5f}")
print(f"Mean Squared Error: {mse:.5f}")
# Out:
# Mean Absolute Error: 0.08399
# Mean Squared Error: 0.01559

# %%
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)

print(f"Mean Absolute Error: {mae:.5f}")
print(f"Mean Squared Error: {mse:.5f}")
# Out:
# Mean Absolute Error: 0.08110
# Mean Squared Error: 0.01454
